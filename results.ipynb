# %%
from util import load_pickle
import matplotlib.pyplot as plt

# %%
h = load_pickle('agent/history')

# %% [markdown]
# ### Return

# %%
plt.plot(h['return'])

# %% [markdown]
# ### Loss

# %%
plt.plot(h['loss'])
