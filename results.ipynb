# %%
from util import load_pickle
import matplotlib.pyplot as plt

# %%
h = load_pickle('agent/history')

# %% [markdown]
# ### Loss

# %%
plt.plot(h['loss'])

# %% [markdown]
# ### Return

# %%
plt.plot(h['return'])

# %%
plt.plot(h['loss'])

# %% [markdown]
# ### Return

# %%
plt.plot(h['return'])
